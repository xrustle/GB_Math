# %% [markdown]
# # Производные функций нескольких переменных

# %% [markdown]
# ### 1. Найти область определения функции

# %% [markdown]
# $\displaystyle z=\sqrt{1-x^{3}}+\ln \left(y^{2}-1\right)$

# %% [markdown]
# $\left\{\begin{array}{l}{1-x^{3} \geqslant 0} \\ {y^{2}-1>0}\end{array}\right.$

# %% [markdown]
# $\left\{\begin{array}{l}{x^{3} \leqslant 1} \\ {y^{2}>1}\end{array}\right.$

# %% [markdown]
# $\left\{\begin{array}{l}{x \leqslant 1} \\ {\left[\begin{array}{l}{y>1} \\ {y<-1}\end{array}\right.}\end{array}\right.$

# %% [markdown]
# $x \in (-\infty, 1]$<br>$y \in (-\infty, -1)\cup(1, +\infty)$

# %% [markdown]
# ### 2. Найти производные 1-го порядка функции

# %% [markdown]
# $\displaystyle z=\left(1+\frac{\ln x}{\ln y}\right)^{3}$

# %% [markdown]
# $\displaystyle z'_x = 3\left(1+\frac{\ln{x}}{\ln{y}}\right)^2\left(1+\frac{\ln{x}}{\ln{y}}\right)'_x = 3\left(1+\frac{\ln{x}}{\ln{y}}\right)^2\cdot\frac{1}{x\ln{y}} = \frac{3(\ln{x}+\ln{y})^2}{x\ln^3 y}$

# %% [markdown]
# $\displaystyle z'_y = 3\left(1+\frac{\ln{x}}{\ln{y}}\right)^2\left(1+\frac{\ln{x}}{\ln{y}}\right)'_y =3\left(1+\frac{\ln{x}}{\ln{y}}\right)^2 \cdot \ln x \left(-\frac{1}{\ln^2 y}\right)\cdot (\ln y)'_y = -3\left(1+\frac{\ln{x}}{\ln{y}}\right)^2 \cdot \frac{\ln x}{y \ln^2 y} = -\frac{3\ln x (\ln x + \ln y)^2}{y\ln^4 y}$

# %% [markdown]
# ### 3. Найти полный дифференциал функции в точке $(1;1)$

# %% [markdown]
# $\displaystyle z=\sqrt{2 x y+\cos \frac{x}{y}}$

# %% [markdown]
# $\displaystyle dz = \frac{\delta z}{\delta x}dx + \frac{\delta z}{\delta y}dy$

# %% [markdown]
# $\displaystyle z'_x = \frac{\left(2xy + \cos\frac{x}{y}\right)'_x}{2\sqrt{2xy + \cos\frac{x}{y}}} = \frac{2y - \frac{1}{y}\sin\frac{x}{y}}{2\sqrt{2xy + \cos\frac{x}{y}}}$

# %% [markdown]
# $\displaystyle z'_x(1;1) = \frac{2-\sin{1}}{2\sqrt{2 + \cos{1}}} = \frac{(2-\sin{1})\sqrt{2 + \cos{1}}}{2(2 + \cos{1})}$

# %% [markdown]
# $\displaystyle z'_y = \frac{\left(2xy + \cos\frac{x}{y}\right)'_y}{2\sqrt{2xy + \cos\frac{x}{y}}} = \frac{2x - \left(\frac{x}{y}\right)'_y\sin\frac{x}{y}}{2\sqrt{2xy + \cos\frac{x}{y}}} = \frac{2x + \frac{x}{y^2}\sin\frac{x}{y}}{2\sqrt{2xy + \cos\frac{x}{y}}}$

# %% [markdown]
# $\displaystyle z'_y(1;1) = \frac{2+\sin{1}}{2\sqrt{2 + \cos{1}}} = \frac{(2+\sin{1})\sqrt{2 + \cos{1}}}{2(2 + \cos{1})}$

# %% [markdown]
# $\displaystyle dz(1; 1) = \frac{(2-\sin{1})\sqrt{2 + \cos{1}}}{2(2 + \cos{1})}dx + \frac{(2+\sin{1})\sqrt{2 + \cos{1}}}{2(2 + \cos{1})}dy$

# %% [markdown]
# ### 4. Исследовать на экстремум функцию

# %% [markdown]
# $\displaystyle z=x^{2}+x y+y^{2}-6 x-9 y$

# %% [markdown]
# $\left\{\begin{array}{l}{z'_x = 2x + y - 6}\\{z'_y = x + 2y - 9}\end{array}\right.$

# %% [markdown]
# $\left\{\begin{array}{l}{2x + y - 6 = 0}\\{x + 2y - 9 = 0}\end{array}\right.$

# %% [markdown]
# $\left\{\begin{array}{l}{3x + 3y = 15}\\{x + 2y - 9 = 0}\end{array}\right.$

# %% [markdown]
# $\left\{\begin{array}{l}{x + y = 5}\\{y = 4}\end{array}\right.$

# %% [markdown]
# $\left\{\begin{array}{l}{x = 1}\\{y = 4}\end{array}\right.$

# %% [markdown]
# $(1; 4)$ - единственная критическая точка.

# %% [markdown]
# $z''_{xx} = (2x + y - 6)'_x = 2$

# %% [markdown]
# $z''_{xy} = (2x + y - 6)'_y = 1$

# %% [markdown]
# $z''_{yy} = (x + 2y - 9)'_y = 2$

# %% [markdown]
# $\left|\begin{array}{cc}z''_{xx} & z''_{xy} \\ z''_{xy} & z''_{yy}\end{array}\right|=$
# $\left|\begin{array}{cc}2 & 1 \\ 1 & 2\end{array}\right| = 3 > 0$

# %% [markdown]
# $z''_{xx} = 2 > 0 \Rightarrow (1; 4)$ - точка локального минимума.

# %%
import numpy as np
from matplotlib import cm
import pylab
from mpl_toolkits.mplot3d import Axes3D

x = np.arange (-2, 4, 0.1)
y = np.arange (-1, 7, 0.1)
x, y = np.meshgrid(x, y)
z = x**2 + x*y + y**2 - 6 * x - 9 * y

fig = pylab.figure()
axes = Axes3D(fig)

axes.plot_surface(x, y, z, rstride=4, cstride=4, cmap = cm.Spectral)

axes.set_xlabel('$x$')
axes.set_ylabel('$y$')
axes.set_zlabel('$z$')

axes.view_init(15, 15)
